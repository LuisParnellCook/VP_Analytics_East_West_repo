# %%
import pandas as pd

# Load your datasets (**replaced the event study abnormal returns csv with corrected version**)
df_ar = pd.read_csv("event_study_abnormal_returns_panel_20260224.csv")
df_reg = pd.read_csv("full_event_regimes.csv")

# %%
df_ar.head()
# Out:
#           event_id ticker        date  event_day  abnormal_return
# 0  AAPL_2005-07-13   AAPL  2005-06-23        -20         0.026191
# 1  AAPL_2005-07-13   AAPL  2005-06-24        -19        -0.010009
# 2  AAPL_2005-07-13   AAPL  2005-06-27        -16        -0.007323
# 3  AAPL_2005-07-13   AAPL  2005-06-28        -15        -0.016779
# 4  AAPL_2005-07-13   AAPL  2005-06-29        -14        -0.019461

# %%
df_reg.head()
# Out:
#   fiscalDateEnding reportedDate  reportedEPS  estimatedEPS  surprise  \
# 0       2005-09-30   2005-10-11         0.01          0.01       0.0
# 1       2005-12-31   2006-01-18         0.02          0.02       0.0
# 2       2006-03-31   2006-04-19         0.02          0.02       0.0
# 3       2006-06-30   2006-07-19         0.02          0.02       0.0
# 4       2006-09-30   2006-10-18         0.02          0.02       0.0
#
#    surprisePercentage   reportTime symbol  totalRevenue  grossProfit  ...  \
# 0                 0.0  post-market   AAPL    3678000000   1035000000  ...
# 1                 0.0  post-market   AAPL    5749000000   1564000000  ...
# 2                 0.0  post-market   AAPL    4359000000   1297000000  ...
# 3                 0.0  post-market   AAPL    4370000000   1325000000  ...
# 4                 0.0  post-market   AAPL    4370000000   1412000000  ...
#
#           event_id  ticker  revenue_growth  margin_trend  profitability  \
# 0  AAPL_2005-09-30    AAPL             NaN           NaN       0.113649
# 1  AAPL_2005-12-31    AAPL        0.563078     -0.018633       0.130457
# 2  AAPL_2006-03-31    AAPL       -0.241781     -0.004220       0.121358
# 3  AAPL_2006-06-30    AAPL        0.002524      0.013951       0.129519
# 4  AAPL_2006-09-30    AAPL        0.000000      0.016018       0.139130
#
#   revenue_growth_regime eps_surprise_regime  profitability_regime  \
# 0               missing               small                medium
# 1           high_growth               small                medium
# 2       negative_growth               small                medium
# 3       moderate_growth               small                medium
# 4       moderate_growth               small                medium
#
#    margin_trend_regime  financial_strength_regime
# 0              missing                      mixed
# 1          contraction                      mixed
# 2               stable                      mixed
# 3            expansion                      mixed
# 4            expansion                      mixed
#
# [5 rows x 25 columns]

# %%
# (**Fix for incorrect event_id column in full_event_regimes csv**)

# Ensure reportedDate is datetime
df_reg["reportedDate"] = pd.to_datetime(df_reg["reportedDate"], errors="coerce")

# Build event_id that matches your corrected event-study panel (ticker + reportedDate)
df_reg["event_id_reported"] = (
    df_reg["ticker"].astype(str) + "_" + df_reg["reportedDate"].dt.strftime("%Y-%m-%d")
)

# %%
df_reg.head()
# Out:
#   fiscalDateEnding reportedDate  reportedEPS  estimatedEPS  surprise  \
# 0       2005-09-30   2005-10-11         0.01          0.01       0.0
# 1       2005-12-31   2006-01-18         0.02          0.02       0.0
# 2       2006-03-31   2006-04-19         0.02          0.02       0.0
# 3       2006-06-30   2006-07-19         0.02          0.02       0.0
# 4       2006-09-30   2006-10-18         0.02          0.02       0.0
#
#    surprisePercentage   reportTime symbol  totalRevenue  grossProfit  ...  \
# 0                 0.0  post-market   AAPL    3678000000   1035000000  ...
# 1                 0.0  post-market   AAPL    5749000000   1564000000  ...
# 2                 0.0  post-market   AAPL    4359000000   1297000000  ...
# 3                 0.0  post-market   AAPL    4370000000   1325000000  ...
# 4                 0.0  post-market   AAPL    4370000000   1412000000  ...
#
#    ticker  revenue_growth  margin_trend  profitability  revenue_growth_regime  \
# 0    AAPL             NaN           NaN       0.113649                missing
# 1    AAPL        0.563078     -0.018633       0.130457            high_growth
# 2    AAPL       -0.241781     -0.004220       0.121358        negative_growth
# 3    AAPL        0.002524      0.013951       0.129519        moderate_growth
# 4    AAPL        0.000000      0.016018       0.139130        moderate_growth
#
#   eps_surprise_regime profitability_regime  margin_trend_regime  \
# 0               small               medium              missing
# 1               small               medium          contraction
# 2               small               medium               stable
# 3               small               medium            expansion
# 4               small               medium            expansion
#
#    financial_strength_regime  event_id_reported
# 0                      mixed    AAPL_2005-10-11
# 1                      mixed    AAPL_2006-01-18
# 2                      mixed    AAPL_2006-04-19
# 3                      mixed    AAPL_2006-07-19
# 4                      mixed    AAPL_2006-10-18
#
# [5 rows x 26 columns]

# %%
# Compute CAR windows for each event
def compute_car(df_ar, t1, t2, label):
    car = (
        df_ar[(df_ar["event_day"] >= t1) & (df_ar["event_day"] <= t2)]
        .groupby("event_id")["abnormal_return"]
        .sum()
        .reset_index()
        .rename(columns={"abnormal_return": label})
    )
    return car

car_m1_p1 = compute_car(df_ar, -1, 1, "CAR_m1_p1")
car_m2_p2 = compute_car(df_ar, -2, 2, "CAR_m2_p2")
car_m5_p5 = compute_car(df_ar, -5, 5, "CAR_m5_p5")
car_p5_p20 = compute_car(df_ar, 5, 20, "CAR_p5_p20")

# %%
# Merge CAR windows into the event‑level dataset (**Change the merges to use the new key**)
df = df_reg.copy()

df = df.merge(
    car_m1_p1,
    left_on="event_id_reported",
    right_on="event_id",
    how="left"
).drop(columns=["event_id"], errors="ignore")

df = df.merge(
    car_m2_p2,
    left_on="event_id_reported",
    right_on="event_id",
    how="left"
).drop(columns=["event_id"], errors="ignore")

df = df.merge(
    car_m5_p5,
    left_on="event_id_reported",
    right_on="event_id",
    how="left"
).drop(columns=["event_id"], errors="ignore")

df = df.merge(
    car_p5_p20,
    left_on="event_id_reported",
    right_on="event_id",
    how="left"
).drop(columns=["event_id"], errors="ignore")

# %%
df.head()
# Out:
#   fiscalDateEnding reportedDate  reportedEPS  estimatedEPS  surprise  \
# 0       2005-09-30   2005-10-11         0.01          0.01       0.0
# 1       2005-12-31   2006-01-18         0.02          0.02       0.0
# 2       2006-03-31   2006-04-19         0.02          0.02       0.0
# 3       2006-06-30   2006-07-19         0.02          0.02       0.0
# 4       2006-09-30   2006-10-18         0.02          0.02       0.0
#
#    surprisePercentage   reportTime symbol  totalRevenue  grossProfit  ...  \
# 0                 0.0  post-market   AAPL    3678000000   1035000000  ...
# 1                 0.0  post-market   AAPL    5749000000   1564000000  ...
# 2                 0.0  post-market   AAPL    4359000000   1297000000  ...
# 3                 0.0  post-market   AAPL    4370000000   1325000000  ...
# 4                 0.0  post-market   AAPL    4370000000   1412000000  ...
#
#    eps_surprise_regime  profitability_regime  margin_trend_regime  \
# 0                small                medium              missing
# 1                small                medium          contraction
# 2                small                medium               stable
# 3                small                medium            expansion
# 4                small                medium            expansion
#
#    financial_strength_regime  event_id_reported       event_id_y CAR_m1_p1  \
# 0                      mixed    AAPL_2005-10-11  AAPL_2005-10-11  0.007234
# 1                      mixed    AAPL_2006-01-18  AAPL_2006-01-18 -0.075341
# 2                      mixed    AAPL_2006-04-19  AAPL_2006-04-19  0.015041
# 3                      mixed    AAPL_2006-07-19  AAPL_2006-07-19  0.146301
# 4                      mixed    AAPL_2006-10-18  AAPL_2006-10-18  0.057448
#
#    CAR_m2_p2  CAR_m5_p5  CAR_p5_p20
# 0   0.077716   0.057094    0.017414
# 1  -0.062981  -0.036115   -0.144021
# 2   0.012303  -0.003040    0.059703
# 3   0.199178   0.163703    0.045687
# 4   0.068848   0.062844   -0.031069
#
# [5 rows x 31 columns]

# %%
# Export DataFrame for further analysis
df.to_csv(
    "earnings_panel_with_CAR_p5_p20_20260224.csv",
    index=False
)

# %%
# Add EPS‑surprise binary variable
df["eps_bin2"] = (df["surprise"] > 0).astype(int)

# %%
# Split the dataset by company
companies = ["AAPL", "GOOGL", "NVDA"]
company_data = {c: df[df["ticker"] == c].copy() for c in companies}

# %%
# Company‑level regressions (AR and CAR windows)
import statsmodels.api as sm

def run_regression(df, y_col):
    X = sm.add_constant(df[["eps_bin2"]])
    y = df[y_col]
    return sm.OLS(y, X).fit()

results = {}

for c in companies:
    d = company_data[c]
    results[c] = {
        "AR0": run_regression(d, "AR0") if "AR0" in d.columns else None,
        "CAR_m1_p1": run_regression(d, "CAR_m1_p1"),
        "CAR_m2_p2": run_regression(d, "CAR_m2_p2"),
        "CAR_m5_p5": run_regression(d, "CAR_m5_p5"),
    }

# %%
for c in companies:
    print(f"\n=== {c} ===")
    for k, model in results[c].items():
        if model is not None:
            print(f"\n--- {k} ---")
            print(model.summary())
# Out:
# === AAPL ===
#
# --- CAR_m1_p1 ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              CAR_m1_p1   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     1.710
# Date:                Tue, 24 Feb 2026   Prob (F-statistic):              0.195
# Time:                        22:41:18   Log-Likelihood:                 141.75
# No. Observations:                  81   AIC:                            -279.5
# Df Residuals:                      79   BIC:                            -274.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0040      0.012     -0.341      0.734      -0.028       0.019
# eps_bin2       0.0169      0.013      1.308      0.195      -0.009       0.043
# ==============================================================================
# Omnibus:                        5.358   Durbin-Watson:                   1.788
# Prob(Omnibus):                  0.069   Jarque-Bera (JB):                6.024
# Skew:                           0.290   Prob(JB):                       0.0492
# Kurtosis:                       4.204   Cond. No.                         4.80
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# --- CAR_m2_p2 ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              CAR_m2_p2   R-squared:                       0.016
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     1.261
# Date:                Tue, 24 Feb 2026   Prob (F-statistic):              0.265
# Time:                        22:41:18   Log-Likelihood:                 125.02
# No. Observations:                  81   AIC:                            -246.0
# Df Residuals:                      79   BIC:                            -241.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0032      0.015     -0.218      0.828      -0.032       0.026
# eps_bin2       0.0178      0.016      1.123      0.265      -0.014       0.049
# ==============================================================================
# Omnibus:                        9.916   Durbin-Watson:                   1.947
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):               22.932
# Skew:                           0.200   Prob(JB):                     1.05e-05
# Kurtosis:                       5.576   Cond. No.                         4.80
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# --- CAR_m5_p5 ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              CAR_m5_p5   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     1.369
# Date:                Tue, 24 Feb 2026   Prob (F-statistic):              0.245
# Time:                        22:41:18   Log-Likelihood:                 126.05
# No. Observations:                  81   AIC:                            -248.1
# Df Residuals:                      79   BIC:                            -243.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0071      0.014     -0.492      0.624      -0.036       0.021
# eps_bin2       0.0183      0.016      1.170      0.245      -0.013       0.049
# ==============================================================================
# Omnibus:                        3.489   Durbin-Watson:                   2.282
# Prob(Omnibus):                  0.175   Jarque-Bera (JB):                3.526
# Skew:                           0.125   Prob(JB):                        0.172
# Kurtosis:                       3.991   Cond. No.                         4.80
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# === GOOGL ===
#
# --- CAR_m1_p1 ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              CAR_m1_p1   R-squared:                       0.210
# Model:                            OLS   Adj. R-squared:                  0.200
# Method:                 Least Squares   F-statistic:                     20.96
# Date:                Tue, 24 Feb 2026   Prob (F-statistic):           1.72e-05
# Time:                        22:41:18   Log-Likelihood:                 128.04
# No. Observations:                  81   AIC:                            -252.1
# Df Residuals:                      79   BIC:                            -247.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0254      0.010     -2.569      0.012      -0.045      -0.006
# eps_bin2       0.0550      0.012      4.578      0.000       0.031       0.079
# ==============================================================================
# Omnibus:                        1.741   Durbin-Watson:                   2.363
# Prob(Omnibus):                  0.419   Jarque-Bera (JB):                1.313
# Skew:                           0.073   Prob(JB):                        0.519
# Kurtosis:                       2.394   Cond. No.                         3.29
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# --- CAR_m2_p2 ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              CAR_m2_p2   R-squared:                       0.193
# Model:                            OLS   Adj. R-squared:                  0.182
# Method:                 Least Squares   F-statistic:                     18.84
# Date:                Tue, 24 Feb 2026   Prob (F-statistic):           4.17e-05
# Time:                        22:41:18   Log-Likelihood:                 123.07
# No. Observations:                  81   AIC:                            -242.1
# Df Residuals:                      79   BIC:                            -237.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0272      0.011     -2.591      0.011      -0.048      -0.006
# eps_bin2       0.0554      0.013      4.340      0.000       0.030       0.081
# ==============================================================================
# Omnibus:                        1.820   Durbin-Watson:                   2.387
# Prob(Omnibus):                  0.402   Jarque-Bera (JB):                1.379
# Skew:                           0.100   Prob(JB):                        0.502
# Kurtosis:                       2.393   Cond. No.                         3.29
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# --- CAR_m5_p5 ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              CAR_m5_p5   R-squared:                       0.208
# Model:                            OLS   Adj. R-squared:                  0.198
# Method:                 Least Squares   F-statistic:                     20.75
# Date:                Tue, 24 Feb 2026   Prob (F-statistic):           1.88e-05
# Time:                        22:41:18   Log-Likelihood:                 114.25
# No. Observations:                  81   AIC:                            -224.5
# Df Residuals:                      79   BIC:                            -219.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0354      0.012     -3.021      0.003      -0.059      -0.012
# eps_bin2       0.0648      0.014      4.555      0.000       0.036       0.093
# ==============================================================================
# Omnibus:                        4.085   Durbin-Watson:                   2.470
# Prob(Omnibus):                  0.130   Jarque-Bera (JB):                2.245
# Skew:                           0.138   Prob(JB):                        0.325
# Kurtosis:                       2.233   Cond. No.                         3.29
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# === NVDA ===
#
# --- CAR_m1_p1 ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              CAR_m1_p1   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     1.481
# Date:                Tue, 24 Feb 2026   Prob (F-statistic):              0.227
# Time:                        22:41:18   Log-Likelihood:                 94.389
# No. Observations:                  81   AIC:                            -184.8
# Df Residuals:                      79   BIC:                            -180.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0040      0.018     -0.220      0.826      -0.040       0.032
# eps_bin2       0.0249      0.020      1.217      0.227      -0.016       0.065
# ==============================================================================
# Omnibus:                        5.321   Durbin-Watson:                   1.832
# Prob(Omnibus):                  0.070   Jarque-Bera (JB):                5.653
# Skew:                          -0.321   Prob(JB):                       0.0592
# Kurtosis:                       4.124   Cond. No.                         4.03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# --- CAR_m2_p2 ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              CAR_m2_p2   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.9589
# Date:                Tue, 24 Feb 2026   Prob (F-statistic):              0.330
# Time:                        22:41:18   Log-Likelihood:                 91.711
# No. Observations:                  81   AIC:                            -179.4
# Df Residuals:                      79   BIC:                            -174.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005      0.019     -0.027      0.978      -0.038       0.037
# eps_bin2       0.0207      0.021      0.979      0.330      -0.021       0.063
# ==============================================================================
# Omnibus:                        6.098   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.047   Jarque-Bera (JB):                7.336
# Skew:                          -0.316   Prob(JB):                       0.0255
# Kurtosis:                       4.332   Cond. No.                         4.03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# --- CAR_m5_p5 ---
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              CAR_m5_p5   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.6316
# Date:                Tue, 24 Feb 2026   Prob (F-statistic):              0.429
# Time:                        22:41:18   Log-Likelihood:                 88.700
# No. Observations:                  81   AIC:                            -173.4
# Df Residuals:                      79   BIC:                            -168.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0030      0.019     -0.157      0.876      -0.041       0.035
# eps_bin2       0.0174      0.022      0.795      0.429      -0.026       0.061
# ==============================================================================
# Omnibus:                        6.165   Durbin-Watson:                   2.021
# Prob(Omnibus):                  0.046   Jarque-Bera (JB):                6.881
# Skew:                          -0.365   Prob(JB):                       0.0321
# Kurtosis:                       4.227   Cond. No.                         4.03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Company‑specific CAR distribution plots
import seaborn as sns
import matplotlib.pyplot as plt

def plot_car_by_company(df, company, car_col):
    plt.figure(figsize=(8,6))
    sns.histplot(df[car_col], bins=30, kde=True)
    plt.title(f"{company}: Distribution of {car_col}")
    plt.xlabel("CAR")
    plt.ylabel("Frequency")
    plt.grid(True)
    plt.show()

for c in companies:
    d = company_data[c]
    plot_car_by_company(d, c, "CAR_m1_p1")
    plot_car_by_company(d, c, "CAR_m2_p2")
    plot_car_by_company(d, c, "CAR_m5_p5")

# %%
# Company‑specific CAR by EPS‑surprise plots
def plot_car_eps(df, company, car_col):
    plt.figure(figsize=(8,6))
    sns.kdeplot(data=df, x=car_col, hue="eps_bin2", fill=True)
    plt.title(f"{company}: {car_col} by EPS Surprise")
    plt.xlabel("CAR")
    plt.ylabel("Density")
    plt.show()

for c in companies:
    d = company_data[c]
    plot_car_eps(d, c, "CAR_m1_p1")
    plot_car_eps(d, c, "CAR_m2_p2")
    plot_car_eps(d, c, "CAR_m5_p5")

# %%
import pandas as pd

metrics = [
    "profitability_regime",
    "margin_trend_regime",
    "revenue_growth_regime",
    "financial_strength_regime"
]

car_cols = ["CAR_m1_p1", "CAR_m2_p2", "CAR_m5_p5"]

sensitivity = {}

for company in ["AAPL", "GOOGL", "NVDA"]:
    df_c = df[df["ticker"] == company]
    sensitivity[company] = {}
    
    for metric in metrics:
        stats = (
            df_c.groupby(metric)[car_cols]
            .agg(["mean", "std", "median"])
        )
        sensitivity[company][metric] = stats

# %%
df.columns
# Out:
# Index(['fiscalDateEnding', 'reportedDate', 'reportedEPS', 'estimatedEPS',
#        'surprise', 'surprisePercentage', 'reportTime', 'symbol',
#        'totalRevenue', 'grossProfit', 'operatingIncome', 'netIncome',
#        'grossMargin', 'operatingMargin', 'netMargin', 'event_id_x', 'ticker',
#        'revenue_growth', 'margin_trend', 'profitability',
#        'revenue_growth_regime', 'eps_surprise_regime', 'profitability_regime',
#        'margin_trend_regime', 'financial_strength_regime', 'event_id_reported',
#        'event_id_y', 'CAR_m1_p1', 'CAR_m2_p2', 'CAR_m5_p5', 'CAR_p5_p20',
#        'eps_bin2'],
#       dtype='object')

# %%
df.head()
# Out:
#   fiscalDateEnding reportedDate  reportedEPS  estimatedEPS  surprise  \
# 0       2005-09-30   2005-10-11         0.01          0.01       0.0
# 1       2005-12-31   2006-01-18         0.02          0.02       0.0
# 2       2006-03-31   2006-04-19         0.02          0.02       0.0
# 3       2006-06-30   2006-07-19         0.02          0.02       0.0
# 4       2006-09-30   2006-10-18         0.02          0.02       0.0
#
#    surprisePercentage   reportTime symbol  totalRevenue  grossProfit  ...  \
# 0                 0.0  post-market   AAPL    3678000000   1035000000  ...
# 1                 0.0  post-market   AAPL    5749000000   1564000000  ...
# 2                 0.0  post-market   AAPL    4359000000   1297000000  ...
# 3                 0.0  post-market   AAPL    4370000000   1325000000  ...
# 4                 0.0  post-market   AAPL    4370000000   1412000000  ...
#
#    profitability_regime  margin_trend_regime  financial_strength_regime  \
# 0                medium              missing                      mixed
# 1                medium          contraction                      mixed
# 2                medium               stable                      mixed
# 3                medium            expansion                      mixed
# 4                medium            expansion                      mixed
#
#    event_id_reported       event_id_y CAR_m1_p1 CAR_m2_p2  CAR_m5_p5  \
# 0    AAPL_2005-10-11  AAPL_2005-10-11  0.007234  0.077716   0.057094
# 1    AAPL_2006-01-18  AAPL_2006-01-18 -0.075341 -0.062981  -0.036115
# 2    AAPL_2006-04-19  AAPL_2006-04-19  0.015041  0.012303  -0.003040
# 3    AAPL_2006-07-19  AAPL_2006-07-19  0.146301  0.199178   0.163703
# 4    AAPL_2006-10-18  AAPL_2006-10-18  0.057448  0.068848   0.062844
#
#    CAR_p5_p20  eps_bin2
# 0    0.017414         0
# 1   -0.144021         0
# 2    0.059703         0
# 3    0.045687         0
# 4   -0.031069         0
#
# [5 rows x 32 columns]

# %%
# Export DataFrame for further analysis
df.to_csv(
    "event_level_financial_metrics_with_CAR.csv",
    index=False
)

# %%
df_c = df[df["ticker"] == company]

# %%
# AAPL    many rows
# GOOGL   many rows
# NVDA    0 rows

# %%
# value_Counts()

# %%
df["ticker"].value_counts()
# Out:
# ticker
# AAPL     81
# GOOGL    81
# NVDA     81
# Name: count, dtype: int64

# %%
metrics = [
    "profitability_regime",
    "margin_trend_regime",
    "revenue_growth_regime",
    "financial_strength_regime"
]

car_cols = ["CAR_m1_p1", "CAR_m2_p2", "CAR_m5_p5"]

sensitivity = {}

for company in ["AAPL", "GOOGL", "NVDA"]:
    print("\n==============================")
    print("Company:", company)
    print("==============================")
    
    df_c = df[df["ticker"] == company]
    sensitivity[company] = {}
    
    for metric in metrics:
        print(f"\n--- Metric: {metric} ---")
        
        stats = (
            df_c.groupby(metric)[car_cols]
            .agg(["mean", "std", "median"])
        )
        
        print(stats)   # ⭐ THIS is what was missing
        
        sensitivity[company][metric] = stats
# Out:
# ==============================
# Company: AAPL
# ==============================
#
# --- Metric: profitability_regime ---
#                      CAR_m1_p1                     CAR_m2_p2            \
#                           mean       std    median      mean       std
# profitability_regime
# high                  0.004870  0.037918  0.002324  0.002742  0.043123
# medium                0.022603  0.051282  0.029942  0.033212  0.065974
#
#                                CAR_m5_p5
#                         median      mean       std    median
# profitability_regime
# high                  0.002886  0.001386  0.045821 -0.000933
# medium                0.040613  0.024766  0.061817  0.030005
#
# --- Metric: margin_trend_regime ---
#                     CAR_m1_p1                     CAR_m2_p2            \
#                          mean       std    median      mean       std
# margin_trend_regime
# contraction          0.004745  0.035854  0.008198  0.004317  0.040743
# expansion            0.008685  0.048918  0.006462  0.008956  0.062383
# missing              0.007234       NaN  0.007234  0.077716       NaN
# stable               0.029029  0.039782  0.024294  0.034591  0.042208
#
#                               CAR_m5_p5
#                        median      mean       std    median
# margin_trend_regime
# contraction          0.009632 -0.000406  0.039906  0.000361
# expansion            0.012696  0.008833  0.059335  0.013097
# missing              0.077716  0.057094       NaN  0.057094
# stable               0.024739  0.025941  0.055229  0.017147
#
# --- Metric: revenue_growth_regime ---
#                       CAR_m1_p1                     CAR_m2_p2            \
#                            mean       std    median      mean       std
# revenue_growth_regime
# high_growth           -0.001962  0.047404 -0.003008 -0.005242  0.056522
# missing                0.007234       NaN  0.007234  0.077716       NaN
# moderate_growth        0.026597  0.047632  0.012764  0.032907  0.061621
# negative_growth        0.013506  0.034522  0.013243  0.015409  0.039823
#
#                                 CAR_m5_p5
#                          median      mean       std    median
# revenue_growth_regime
# high_growth            0.005044 -0.005823  0.053657 -0.009257
# missing                0.077716  0.057094       NaN  0.057094
# moderate_growth        0.004906  0.029925  0.050199  0.022893
# negative_growth        0.016490  0.009775  0.048648  0.008822
#
# --- Metric: financial_strength_regime ---
#                           CAR_m1_p1                     CAR_m2_p2            \
#                                mean       std    median      mean       std
# financial_strength_regime
# mixed                      0.007219  0.044731  0.007234  0.009591  0.056046
# strong_fundamentals        0.018986  0.035669  0.015964  0.018416  0.039920
#
#                                     CAR_m5_p5
#                              median      mean       std    median
# financial_strength_regime
# mixed                      0.013663  0.006636  0.054531  0.008822
# strong_fundamentals        0.022500  0.013431  0.043275  0.015705
#
# ==============================
# Company: GOOGL
# ==============================
#
# --- Metric: profitability_regime ---
#                      CAR_m1_p1                     CAR_m2_p2            \
#                           mean       std    median      mean       std
# profitability_regime
# high                  0.016689  0.059180  0.021545  0.015268  0.061745
# low                   0.041553       NaN  0.041553  0.039713       NaN
# medium               -0.006230  0.043637 -0.013940 -0.008152  0.048640
#
#                                CAR_m5_p5
#                         median      mean       std    median
# profitability_regime
# high                  0.023490  0.014035  0.070749  0.012051
# low                   0.039713  0.053566       NaN  0.053566
# medium               -0.018810 -0.012670  0.048049 -0.014195
#
# --- Metric: margin_trend_regime ---
#                     CAR_m1_p1                     CAR_m2_p2            \
#                          mean       std    median      mean       std
# margin_trend_regime
# contraction         -0.007482  0.053206 -0.007087 -0.009417  0.056697
# expansion            0.028760  0.049166  0.035182  0.027735  0.052386
# missing              0.095637       NaN  0.095637  0.090778       NaN
# stable               0.025610  0.079663  0.029187  0.024223  0.080500
#
#                               CAR_m5_p5
#                        median      mean       std    median
# margin_trend_regime
# contraction         -0.019944 -0.011764  0.061597 -0.018025
# expansion            0.031146  0.023952  0.060642  0.024372
# missing              0.090778  0.123368       NaN  0.123368
# stable               0.034073  0.032134  0.096378  0.036528
#
# --- Metric: revenue_growth_regime ---
#                       CAR_m1_p1                     CAR_m2_p2            \
#                            mean       std    median      mean       std
# revenue_growth_regime
# high_growth            0.002592  0.054442  0.007443 -0.003267  0.054662
# missing                0.095637       NaN  0.095637  0.090778       NaN
# moderate_growth        0.018996  0.061634  0.022166  0.019228  0.064778
# negative_growth        0.000952  0.040482  0.004074  0.000579  0.046235
#
#                                 CAR_m5_p5
#                          median      mean       std    median
# revenue_growth_regime
# high_growth            0.004379 -0.005836  0.064095 -0.002114
# missing                0.090778  0.123368       NaN  0.123368
# moderate_growth        0.027540  0.018866  0.072524  0.006609
# negative_growth        0.007242 -0.005734  0.045618  0.017552
#
# --- Metric: financial_strength_regime ---
#                           CAR_m1_p1                     CAR_m2_p2            \
#                                mean       std    median      mean       std
# financial_strength_regime
# mixed                      0.000286  0.056535 -0.001887 -0.000801  0.059665
# strong_fundamentals        0.034889  0.050171  0.036142  0.032428  0.053805
# weak_fundamentals          0.041553       NaN  0.041553  0.039713       NaN
#
#                                     CAR_m5_p5
#                              median      mean       std    median
# financial_strength_regime
# mixed                     -0.013048 -0.002725  0.066190 -0.012489
# strong_fundamentals        0.033026  0.030356  0.064224  0.033807
# weak_fundamentals          0.039713  0.053566       NaN  0.053566
#
# ==============================
# Company: NVDA
# ==============================
#
# --- Metric: profitability_regime ---
#                      CAR_m1_p1                     CAR_m2_p2            \
#                           mean       std    median      mean       std
# profitability_regime
# high                  0.012313  0.079784  0.009838  0.015053  0.077419
# low                   0.020845  0.124730  0.059016  0.021371  0.134523
# medium                0.016164  0.060677  0.015758  0.014541  0.063932
#
#                                CAR_m5_p5
#                         median      mean       std    median
# profitability_regime
# high                  0.006669  0.010076  0.082454 -0.001128
# low                   0.051000  0.013159  0.124300  0.029887
# medium                0.024127  0.010187  0.070788  0.023892
#
# --- Metric: margin_trend_regime ---
#                     CAR_m1_p1                     CAR_m2_p2            \
#                          mean       std    median      mean       std
# margin_trend_regime
# contraction          0.015639  0.072965  0.019178  0.017878  0.079479
# expansion            0.029943  0.071777  0.023369  0.031831  0.067106
# missing             -0.026617       NaN -0.026617 -0.037978       NaN
# stable              -0.060543  0.082209 -0.037614 -0.075276  0.087661
#
#                               CAR_m5_p5
#                        median      mean       std    median
# margin_trend_regime
# contraction          0.014409  0.013576  0.076719  0.006236
# expansion            0.030525  0.027133  0.072718  0.027389
# missing             -0.037978 -0.048582       NaN -0.048582
# stable              -0.058809 -0.084224  0.093306 -0.048563
#
# --- Metric: revenue_growth_regime ---
#                       CAR_m1_p1                     CAR_m2_p2            \
#                            mean       std    median      mean       std
# revenue_growth_regime
# high_growth            0.015499  0.078377  0.012814  0.013225  0.080080
# missing               -0.026617       NaN -0.026617 -0.037978       NaN
# moderate_growth        0.009538  0.077101  0.014936  0.010489  0.077697
# negative_growth        0.027494  0.077349  0.038413  0.031322  0.082912
#
#                                 CAR_m5_p5
#                          median      mean       std    median
# revenue_growth_regime
# high_growth            0.021305  0.013801  0.078159  0.018049
# missing               -0.037978 -0.048582       NaN -0.048582
# moderate_growth        0.013157  0.001683  0.091021  0.008311
# negative_growth        0.032164  0.023345  0.074333  0.006236
#
# --- Metric: financial_strength_regime ---
#                           CAR_m1_p1                     CAR_m2_p2            \
#                                mean       std    median      mean       std
# financial_strength_regime
# mixed                      0.013180  0.072448  0.016753  0.012872  0.078116
# strong_fundamentals        0.032827  0.081743  0.012814  0.034885  0.075690
# weak_fundamentals         -0.045768  0.182289 -0.045768 -0.043078  0.145186
#
#                                     CAR_m5_p5
#                              median      mean       std    median
# financial_strength_regime
# mixed                      0.016997  0.008751  0.082873  0.006393
# strong_fundamentals        0.021305  0.022485  0.079941  0.008311
# weak_fundamentals         -0.043078 -0.022849  0.090691 -0.022849

# %%
import numpy as np

def sensitivity_score(stats):
    # difference between max and min mean CAR across regimes
    diffs = stats["CAR_m1_p1"]["mean"].max() - stats["CAR_m1_p1"]["mean"].min()
    return diffs

for company in ["AAPL", "GOOGL", "NVDA"]:
    print("\n", company)
    scores = {}
    for metric in metrics:
        stats = sensitivity[company][metric]
        scores[metric] = sensitivity_score(stats)
    print(scores)
# Out:
#  AAPL
# {'profitability_regime': 0.01773307187995833, 'margin_trend_regime': 0.02428446584526519, 'revenue_growth_regime': 0.02855908992291306, 'financial_strength_regime': 0.011767032827149092}
#
#  GOOGL
# {'profitability_regime': 0.047782924275804446, 'margin_trend_regime': 0.10311818960717758, 'revenue_growth_regime': 0.09468426299559128, 'financial_strength_regime': 0.041266758113913476}
#
#  NVDA
# {'profitability_regime': 0.008531581698549251, 'margin_trend_regime': 0.09048546215346795, 'revenue_growth_regime': 0.054111156515313966, 'financial_strength_regime': 0.07859551402356403}

# %% [markdown]
# Apple’s and Google's CAR shifts the most when revenue growth regime changes.
# NVIDIA is the only company where margin trend beats revenue growth.

# %%
sensitivity_scores = {
    "AAPL": {
        "profitability_regime": 0.003909321344729935,
        "margin_trend_regime": 0.016573893464054402,
        "revenue_growth_regime": 0.023438180333077395,
        "financial_strength_regime": 0.0075899144068854695
    },
    "GOOGL": {
        "profitability_regime": 0.0013321610513708834,
        "margin_trend_regime": 0.01784348329307871,
        "revenue_growth_regime": 0.02078714286697741,
        "financial_strength_regime": 0.00013608653556981473
    },
    "NVDA": {
        "profitability_regime": 0.009614634648039615,
        "margin_trend_regime": 0.013233207543839037,
        "revenue_growth_regime": 0.011555075945166464,
        "financial_strength_regime": 0.010371335228634461
    }
}

# %%
top_metric = {
    company: max(scores, key=scores.get)
    for company, scores in sensitivity_scores.items()
}

top_metric
# Out:
# {'AAPL': 'revenue_growth_regime',
#  'GOOGL': 'revenue_growth_regime',
#  'NVDA': 'margin_trend_regime'}

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plot_car_by_metric(df, company, metric, car_col="CAR_m1_p1"):
    df_c = df[df["ticker"] == company]

    plt.figure(figsize=(10,6))
    sns.kdeplot(
        data=df_c,
        x=car_col,
        hue=metric,
        fill=True,
        common_norm=False,
        alpha=0.4
    )
    plt.title(f"{company}: {car_col} by {metric}")
    plt.xlabel("CAR")
    plt.ylabel("Density")
    plt.grid(True)
    plt.show()

for company, metric in top_metric.items():
    plot_car_by_metric(df, company, metric, "CAR_m1_p1")
# Out:
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\1945884928.py:8: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\1945884928.py:8: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\1945884928.py:8: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(

# %%
def boxplot_car(df, company, metric, car_col="CAR_m1_p1"):
    df_c = df[df["ticker"] == company]

    plt.figure(figsize=(10,6))
    sns.boxplot(
        data=df_c,
        x=metric,
        y=car_col,
        palette="Set2"
    )
    plt.title(f"{company}: {car_col} distribution by {metric}")
    plt.xlabel(metric)
    plt.ylabel("CAR")
    plt.grid(True)
    plt.show()

for company, metric in top_metric.items():
    boxplot_car(df, company, metric)
# Out:
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\442716038.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\442716038.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\442716038.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
import numpy as np

# Convert to DataFrame
sens_df = pd.DataFrame(sensitivity_scores).T

plt.figure(figsize=(10,6))
sns.heatmap(
    sens_df,
    annot=True,
    cmap="YlGnBu",
    linewidths=0.5
)
plt.title("Sensitivity of CAR to Financial Metrics (Higher = More Sensitive)")
plt.xlabel("Metric")
plt.ylabel("Company")
plt.show()

# %%
car_windows = ["CAR_m1_p1", "CAR_m2_p2", "CAR_m5_p5"]

# %%
def plot_car_by_metric(df, company, metric, car_col):
    df_c = df[df["ticker"] == company]

    plt.figure(figsize=(10,6))
    sns.kdeplot(
        data=df_c,
        x=car_col,
        hue=metric,
        fill=True,
        common_norm=False,
        alpha=0.4
    )
    plt.title(f"{company}: {car_col} by {metric}")
    plt.xlabel("CAR")
    plt.ylabel("Density")
    plt.grid(True)
    plt.show()

for company, metric in top_metric.items():
    for car_col in car_windows:
        plot_car_by_metric(df, company, metric, car_col)
# Out:
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\2814968851.py:5: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\2814968851.py:5: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\2814968851.py:5: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\2814968851.py:5: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\2814968851.py:5: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\2814968851.py:5: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\2814968851.py:5: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\2814968851.py:5: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\2814968851.py:5: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(

# %%
def boxplot_car(df, company, metric, car_col):
    df_c = df[df["ticker"] == company]

    plt.figure(figsize=(10,6))
    sns.boxplot(
        data=df_c,
        x=metric,
        y=car_col,
        palette="Set2"
    )
    plt.title(f"{company}: {car_col} distribution by {metric}")
    plt.xlabel(metric)
    plt.ylabel("CAR")
    plt.grid(True)
    plt.show()

for company, metric in top_metric.items():
    for car_col in car_windows:
        boxplot_car(df, company, metric, car_col)
# Out:
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\1073145730.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\1073145730.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\1073145730.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\1073145730.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\1073145730.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\1073145730.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\1073145730.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\1073145730.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\1073145730.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %% [markdown]
# AAPL — revenue growth regime
# - CAR_m1_p1: small but visible separation
# - CAR_m2_p2: stronger separation
# - CAR_m5_p5: clearest separation (macro‑adjusted)
# GOOGL — revenue growth regime
# - CAR_m1_p1: muted
# - CAR_m2_p2: clearer
# - CAR_m5_p5: strongest (Google reacts slowly)
# NVDA — margin trend regime
# - CAR_m1_p1: noisy
# - CAR_m2_p2: clearer
# - CAR_m5_p5: very strong separation (NVDA reacts with volatility)

# %% [markdown]
# Filter data from 2021-2024

# %%
df["reportedDate"] = pd.to_datetime(df["reportedDate"])
df_recent = df[(df["reportedDate"].dt.year >= 2021) & (df["reportedDate"].dt.year <= 2024)]

# %%
metrics = [
    "profitability_regime",
    "margin_trend_regime",
    "revenue_growth_regime",
    "financial_strength_regime"
]

car_cols = ["CAR_m1_p1", "CAR_m2_p2", "CAR_m5_p5"]

sensitivity_recent = {}

for company in ["AAPL", "GOOGL", "NVDA"]:
    df_c = df_recent[df_recent["ticker"] == company]
    sensitivity_recent[company] = {}
    
    for metric in metrics:
        stats = (
            df_c.groupby(metric)[car_cols]
            .agg(["mean", "std", "median"])
        )
        
        # sensitivity score = max(mean CAR) - min(mean CAR)
        score = stats["CAR_m1_p1"]["mean"].max() - stats["CAR_m1_p1"]["mean"].min()
        sensitivity_recent[company][metric] = score

# %%
for company, scores in sensitivity_recent.items():
    print("\n", company)
    print(scores)
# Out:
#  AAPL
# {'profitability_regime': 0.0, 'margin_trend_regime': 0.012531702302751087, 'revenue_growth_regime': 0.005844568923032037, 'financial_strength_regime': 0.0042639497728182265}
#
#  GOOGL
# {'profitability_regime': 0.040038159935818454, 'margin_trend_regime': 0.033771396805125316, 'revenue_growth_regime': 0.023579821415516136, 'financial_strength_regime': 0.038466780295173815}
#
#  NVDA
# {'profitability_regime': 0.017693994202138234, 'margin_trend_regime': 0.03517425853031804, 'revenue_growth_regime': 0.0329714585147524, 'financial_strength_regime': 0.03273021329547997}

# %%
import pandas as pd

df_compare = pd.DataFrame({
    "full_sample": sensitivity_scores, 
    "recent_sample": sensitivity_recent
}).T

# %%
compare = {}

for company in ["AAPL", "GOOGL", "NVDA"]:
    compare[company] = pd.DataFrame({
        "full_sample": sensitivity_scores[company],
        "recent_sample": sensitivity_recent[company]
    })

compare
# Out:
# {'AAPL':                            full_sample  recent_sample
#  profitability_regime          0.003909       0.000000
#  margin_trend_regime           0.016574       0.012532
#  revenue_growth_regime         0.023438       0.005845
#  financial_strength_regime     0.007590       0.004264,
#  'GOOGL':                            full_sample  recent_sample
#  profitability_regime          0.001332       0.040038
#  margin_trend_regime           0.017843       0.033771
#  revenue_growth_regime         0.020787       0.023580
#  financial_strength_regime     0.000136       0.038467,
#  'NVDA':                            full_sample  recent_sample
#  profitability_regime          0.009615       0.017694
#  margin_trend_regime           0.013233       0.035174
#  revenue_growth_regime         0.011555       0.032971
#  financial_strength_regime     0.010371       0.032730}

# %%
import matplotlib.pyplot as plt

for company in ["AAPL", "GOOGL", "NVDA"]:
    df_plot = pd.DataFrame({
        "full_sample": sensitivity_scores[company],
        "recent_sample": sensitivity_recent[company]
    })
    
    df_plot.plot(kind="bar", figsize=(10,6), title=f"{company}: Sensitivity Comparison (Full vs 2021–2024)")
    plt.ylabel("Sensitivity Score")
    plt.grid(True)
    plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Convert the recent sensitivity dictionary into a DataFrame
sens_recent_df = pd.DataFrame(sensitivity_recent).T

plt.figure(figsize=(10, 6))
sns.heatmap(
    sens_recent_df,
    annot=True,
    cmap="YlOrRd",
    linewidths=0.5,
    fmt=".4f"
)

plt.title("Sensitivity of CAR to Financial Metrics (2021–2024)\nHigher = More Sensitive")
plt.xlabel("Financial Metric")
plt.ylabel("Company")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Convert dictionaries to DataFrames
sens_full_df = pd.DataFrame(sensitivity_scores).T
sens_recent_df = pd.DataFrame(sensitivity_recent).T

# Create side-by-side heatmaps
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Full sample heatmap
sns.heatmap(
    sens_full_df,
    annot=True,
    cmap="YlOrRd",
    linewidths=0.5,
    fmt=".4f",
    ax=axes[0],
    vmin=min(sens_full_df.min().min(), sens_recent_df.min().min()),
    vmax=max(sens_full_df.max().max(), sens_recent_df.max().max())
)
axes[0].set_title("Sensitivity of CAR to Financial Metrics\nFull Sample (All Years)")
axes[0].set_xlabel("Financial Metric")
axes[0].set_ylabel("Company")

# Recent sample heatmap
sns.heatmap(
    sens_recent_df,
    annot=True,
    cmap="YlOrRd",
    linewidths=0.5,
    fmt=".4f",
    ax=axes[1],
    vmin=min(sens_full_df.min().min(), sens_recent_df.min().min()),
    vmax=max(sens_full_df.max().max(), sens_recent_df.max().max())
)
axes[1].set_title("Sensitivity of CAR to Financial Metrics\nRecent Sample (2021–2024)")
axes[1].set_xlabel("Financial Metric")
axes[1].set_ylabel("")

plt.tight_layout()
plt.show()

# %%
df_recent = df[(df["reportedDate"].dt.year >= 2021) & (df["reportedDate"].dt.year <= 2024)]

# %%
top_metric_recent = {
    company: max(scores, key=scores.get)
    for company, scores in sensitivity_recent.items()
}

top_metric_recent
# Out:
# {'AAPL': 'margin_trend_regime',
#  'GOOGL': 'profitability_regime',
#  'NVDA': 'margin_trend_regime'}

# %%
import seaborn as sns
import matplotlib.pyplot as plt

car_windows = ["CAR_m1_p1", "CAR_m2_p2", "CAR_m5_p5"]

def plot_recent_car(df_recent, company, metric, car_col):
    df_c = df_recent[df_recent["ticker"] == company]

    plt.figure(figsize=(10,6))
    sns.kdeplot(
        data=df_c,
        x=car_col,
        hue=metric,
        fill=True,
        common_norm=False,
        alpha=0.4
    )
    plt.title(f"{company}: {car_col} by {metric} (2021–2024)")
    plt.xlabel("CAR")
    plt.ylabel("Density")
    plt.grid(True)
    plt.show()

for company, metric in top_metric_recent.items():
    for car_col in car_windows:
        plot_recent_car(df_recent, company, metric, car_col)
# Out:
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\949538824.py:10: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\949538824.py:10: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\949538824.py:10: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Convert to DataFrames
sens_full_df = pd.DataFrame(sensitivity_scores).T
sens_recent_df = pd.DataFrame(sensitivity_recent).T

# Compute difference
sens_diff_df = sens_recent_df - sens_full_df

plt.figure(figsize=(10, 6))
sns.heatmap(
    sens_diff_df,
    annot=True,
    cmap="RdBu",
    center=0,
    linewidths=0.5,
    fmt=".4f"
)

plt.title("Change in Sensitivity of CAR to Financial Metrics (2021–2024 minus Full Sample)")
plt.xlabel("Financial Metric")
plt.ylabel("Company")
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

car_windows = ["CAR_m1_p1", "CAR_m2_p2", "CAR_m5_p5"]

# Identify top metric per company (recent)
top_metric_recent = {
    company: max(scores, key=scores.get)
    for company, scores in sensitivity_recent.items()
}

# Prepare figure
fig, axes = plt.subplots(3, 3, figsize=(18, 14))
companies = ["AAPL", "GOOGL", "NVDA"]

for i, company in enumerate(companies):
    metric = top_metric_recent[company]
    df_c = df_recent[df_recent["ticker"] == company]

    for j, car_col in enumerate(car_windows):
        ax = axes[i, j]
        sns.kdeplot(
            data=df_c,
            x=car_col,
            hue=metric,
            fill=True,
            common_norm=False,
            alpha=0.4,
            ax=ax
        )
        ax.set_title(f"{company} — {car_col} by {metric} (2021–2024)")
        ax.set_xlabel("CAR")
        ax.set_ylabel("Density")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\2527629299.py:22: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\2527629299.py:22: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# C:\Users\adyat\AppData\Local\Temp\ipykernel_22704\2527629299.py:22: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(

# %%
df_pre = df[df["reportedDate"].dt.year <= 2020]

sensitivity_pre = {}

for company in ["AAPL", "GOOGL", "NVDA"]:
    df_c = df_pre[df_pre["ticker"] == company]
    sensitivity_pre[company] = {}
    
    for metric in metrics:
        stats = (
            df_c.groupby(metric)[car_cols]
            .agg(["mean", "std", "median"])
        )
        score = stats["CAR_m1_p1"]["mean"].max() - stats["CAR_m1_p1"]["mean"].min()
        sensitivity_pre[company][metric] = score

# %%
compare_pre_recent = {}

for company in ["AAPL", "GOOGL", "NVDA"]:
    compare_pre_recent[company] = pd.DataFrame({
        "2005–2020": sensitivity_pre[company],
        "2021–2024": sensitivity_recent[company]
    })

# %%
sens_pre_df = pd.DataFrame(sensitivity_pre).T
sens_recent_df = pd.DataFrame(sensitivity_recent).T

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.heatmap(
    sens_pre_df,
    annot=True,
    cmap="YlOrRd",
    linewidths=0.5,
    fmt=".4f",
    ax=axes[0]
)
axes[0].set_title("Sensitivity of CAR to Financial Metrics\n2005–2020")

sns.heatmap(
    sens_recent_df,
    annot=True,
    cmap="YlOrRd",
    linewidths=0.5,
    fmt=".4f",
    ax=axes[1]
)
axes[1].set_title("Sensitivity of CAR to Financial Metrics\n2021–2024")

plt.tight_layout()
plt.show()

# %%
sens_full_df = pd.DataFrame(sensitivity_scores).T

fig, axes = plt.subplots(1, 3, figsize=(22, 6))

sns.heatmap(
    sens_full_df,
    annot=True,
    cmap="YlOrRd",
    linewidths=0.5,
    fmt=".4f",
    ax=axes[0]
)
axes[0].set_title("Full Sample (2005–2024)")

sns.heatmap(
    sens_pre_df,
    annot=True,
    cmap="YlOrRd",
    linewidths=0.5,
    fmt=".4f",
    ax=axes[1]
)
axes[1].set_title("Pre‑COVID (2005–2020)")

sns.heatmap(
    sens_recent_df,
    annot=True,
    cmap="YlOrRd",
    linewidths=0.5,
    fmt=".4f",
    ax=axes[2]
)
axes[2].set_title("Post‑COVID (2021–2024)")

plt.tight_layout()
plt.show()

# %% [markdown]
# Apple (AAPL): From Growth → Margins (with Full Sample as the bridge)
# Full Sample (2005–2024)
# Revenue growth is the strongest driver of CAR, followed by margin trend. This reflects Apple’s long expansion period where top‑line acceleration mattered most.
# Pre‑COVID (2005–2020)
# Revenue growth sensitivity is even stronger here — Apple was still in a high‑growth phase, and investors rewarded top‑line momentum.
# Post‑COVID (2021–2024)
# Revenue growth sensitivity declines, while margin trend becomes the dominant driver. Profitability sensitivity collapses to zero, and financial strength becomes more relevant.
# Interpretation
# Apple’s earnings reactions have structurally shifted from growth‑driven to margin‑driven.
# The full‑sample results sit between the two regimes, masking the post‑COVID pivot toward margins.
# Trading implication:
# Use margin‑trend signals rather than revenue growth when positioning around AAPL earnings.
#
# Google (GOOGL): From Growth → Efficiency (with Full Sample showing the transition)
# Full Sample (2005–2024)
# Revenue growth is the strongest predictor of CAR, consistent with Google’s long‑run ad‑driven expansion.
# Pre‑COVID (2005–2020)
# Revenue growth sensitivity is even stronger, and margin trend is also meaningful. Google was rewarded for scale and top‑line acceleration.
# Post‑COVID (2021–2024)
# Revenue growth and margin trend sensitivity collapse sharply.
# Instead, financial strength and profitability become more influential — reflecting Google’s cost‑cutting, layoffs, and efficiency narrative during 2022–2023.
# Interpretation
# Google’s earnings reactions have shifted from growth‑driven to efficiency‑driven.
# The full‑sample results hide this shift because the pre‑COVID period dominates the data.
# Trading implication:
# For GOOGL, emphasize balance‑sheet quality and cost discipline, not growth momentum.
#
# NVIDIA (NVDA): From Cyclical Margins → Explosive Growth Sensitivity
# Full Sample (2005–2024)
# Margin trend is the strongest driver of CAR, reflecting NVIDIA’s cyclical GPU business and sensitivity to product mix.
# Pre‑COVID (2005–2020)
# Margin trend remains dominant, and revenue growth sensitivity is modest. This matches NVIDIA’s pre‑AI cyclical profile.
# Post‑COVID (2021–2024)
# Both revenue growth and margin trend sensitivity increase dramatically, with revenue growth becoming the strongest predictor.
# This reflects the AI supercycle and unprecedented demand for data‑center GPUs.
# Interpretation
# NVIDIA undergoes the most dramatic structural break:
# from a margin‑sensitive cyclical stock → to a hyper‑growth AI leader.
# The full‑sample results understate this shift because the pre‑COVID period dilutes the explosive post‑COVID sensitivity.
# Trading implication:
# NVDA earnings trades should overweight growth acceleration and margin expansion.
