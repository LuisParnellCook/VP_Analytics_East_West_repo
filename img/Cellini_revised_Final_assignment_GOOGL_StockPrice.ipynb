# %%
# Import the necessary libraries.
import pandas as pd
import numpy as np

# Optional - Ignore warnings.
import warnings
warnings.filterwarnings('ignore')

# %%
# Import the dummy date file
date_df = pd.read_csv("date_df.csv")

# %%
# Read the head of data file
date_df.head()
# Out:
#    Index Month_Index
# 0      1     01/1947
# 1      2     02/1947
# 2      3     03/1947
# 3      4     04/1947
# 4      5     05/1947

# %%
# Read data file information
date_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Index        950 non-null    int64
#  1   Month_Index  950 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 15.0+ KB

# %%
# Update data type from object to datetime
date_df["Month_Index"] = pd.to_datetime(date_df["Month_Index"], errors="coerce")

# %%
# Rename the Column name
date_df.rename(columns={'Month_Index': 'Date'}, inplace=True)

# %%
# Read the data file information
date_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Index   950 non-null    int64
#  1   Date    950 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 15.0 KB

# %%
# Read the top row of data file
date_df.head
# Out:
# <bound method NDFrame.head of      Index       Date
# 0        1 1947-01-01
# 1        2 1947-02-01
# 2        3 1947-03-01
# 3        4 1947-04-01
# 4        5 1947-05-01
# ..     ...        ...
# 945    946 2025-10-01
# 946    947 2025-11-01
# 947    948 2025-12-01
# 948    949 2026-01-01
# 949    950 2026-02-01
#
# [950 rows x 2 columns]>

# %%
# Import Consumer Prices Index (CPI) data
cpi_df = pd.read_csv("cpi.csv")

# %%
# Read the top row of Consumer Prices Index (CPI) dataset
cpi_df.head
# Out:
# <bound method NDFrame.head of     observation_date  cpiaucsl
# 0         1947-01-01    21.480
# 1         1947-02-01    21.620
# 2         1947-03-01    22.000
# 3         1947-04-01    22.000
# 4         1947-05-01    21.950
# ..               ...       ...
# 943       2025-08-01   323.364
# 944       2025-09-01   324.368
# 945       2025-10-01       NaN
# 946       2025-11-01   325.031
# 947       2025-12-01   326.030
#
# [948 rows x 2 columns]>

# %%
# Rename the Columns name
cpi_df.rename(columns={'observation_date': 'Date', 'cpiaucsl': 'Consumer price index'}, inplace=True)

# %%
# Read the top row of Consumer Prices Index (CPI) dataset
cpi_df.head
# Out:
# <bound method NDFrame.head of            Date  Consumer price index
# 0    1947-01-01                21.480
# 1    1947-02-01                21.620
# 2    1947-03-01                22.000
# 3    1947-04-01                22.000
# 4    1947-05-01                21.950
# ..          ...                   ...
# 943  2025-08-01               323.364
# 944  2025-09-01               324.368
# 945  2025-10-01                   NaN
# 946  2025-11-01               325.031
# 947  2025-12-01               326.030
#
# [948 rows x 2 columns]>

# %%
# Read Consumer Prices Index (CPI) dataset informaion
cpi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 948 entries, 0 to 947
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  948 non-null    object
#  1   Consumer price index  947 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 14.9+ KB

# %%
# Update data type from object to datetime
cpi_df["Date"] = pd.to_datetime(cpi_df["Date"], errors="coerce")

# %%
# Read Consumer Prices Index (CPI) dataset informaion
cpi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 948 entries, 0 to 947
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  948 non-null    datetime64[ns]
#  1   Consumer price index  947 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 14.9 KB

# %%
# Generates a statistical summary of Consumer Prices Index (CPI)
cpi_df.describe()
# Out:
#                                 Date  Consumer price index
# count                            948            947.000000
# mean   1986-06-16 14:01:31.139240512            123.848383
# min              1947-01-01 00:00:00             21.480000
# 25%              1966-09-23 12:00:00             32.800000
# 50%              1986-06-16 00:00:00            109.600000
# 75%              2006-03-08 18:00:00            199.550000
# max              2025-12-01 00:00:00            326.030000
# std                              NaN             89.214260

# %%
# Convert to changes in the CPI
cpi_df['Changes in the CPI'] = cpi_df['Consumer price index'].pct_change(periods=1) * 100

# %%
# Read the top row of changes in the CPI dataset
cpi_df.head()
# Out:
#         Date  Consumer price index  Changes in the CPI
# 0 1947-01-01                 21.48                 NaN
# 1 1947-02-01                 21.62            0.651769
# 2 1947-03-01                 22.00            1.757632
# 3 1947-04-01                 22.00            0.000000
# 4 1947-05-01                 21.95           -0.227273

# %%
# Generates a statistical summary of Consumer Prices Index (CPI)
cpi_df.describe()
# Out:
#                                 Date  Consumer price index  Changes in the CPI
# count                            948            947.000000          947.000000
# mean   1986-06-16 14:01:31.139240512            123.848383            0.288199
# min              1947-01-01 00:00:00             21.480000           -1.770548
# 25%              1966-09-23 12:00:00             32.800000            0.100637
# 50%              1986-06-16 00:00:00            109.600000            0.246914
# 75%              2006-03-08 18:00:00            199.550000            0.436806
# max              2025-12-01 00:00:00            326.030000            1.964286
# std                              NaN             89.214260            0.340731

# %%
# Import Unemployment rate data
unemploy_df = pd.read_csv("unemployment.csv")

# %%
# Read the top row of Unemployment rate dataset
unemploy_df.head()
# Out:
#   observation_date  unemployment_rate
# 0       1948-01-01                3.4
# 1       1948-02-01                3.8
# 2       1948-03-01                4.0
# 3       1948-04-01                3.9
# 4       1948-05-01                3.5

# %%
# Read Unemployment rate dataset informaion
unemploy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 936 entries, 0 to 935
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   observation_date   936 non-null    object
#  1   unemployment_rate  935 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 14.8+ KB

# %%
# Rename the Column name
unemploy_df.rename(columns={'observation_date': 'Date', 'unemployment_rate': 'Unemployment Rate'}, inplace=True)

# %%
# Update data type from object to datetime
unemploy_df["Date"] = pd.to_datetime(unemploy_df["Date"], errors="coerce")

# %%
# Read Unemployment rate dataset informaion
unemploy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 936 entries, 0 to 935
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               936 non-null    datetime64[ns]
#  1   Unemployment Rate  935 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 14.8 KB

# %%
# Generates a statistical summary of Unemployment rate
unemploy_df.describe()
# Out:
#                                 Date  Unemployment Rate
# count                            936         935.000000
# mean   1986-12-16 05:07:41.538461568           5.666524
# min              1948-01-01 00:00:00           2.500000
# 25%              1967-06-23 12:00:00           4.300000
# 50%              1986-12-16 12:00:00           5.500000
# 75%              2006-06-08 12:00:00           6.700000
# max              2025-12-01 00:00:00          14.800000
# std                              NaN           1.706049

# %%
# Import Gross Domestic Product (GDP) data
gdp_df = pd.read_csv("gdp.csv")

# %%
# Read the top row of Gross Domestic Product (GDP) dataset
gdp_df.head()
# Out:
#   observation_date  gdp_growth
# 0        10/1/2015         0.7
# 1         1/1/2016         2.3
# 2         4/1/2016         1.3
# 3         7/1/2016         2.9
# 4        10/1/2016         2.2

# %%
# Read Gross Domestic Product (GDP) dataset informaion
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   observation_date  40 non-null     object
#  1   gdp_growth        40 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 772.0+ bytes

# %%
# Rename the Columns name
gdp_df.rename(columns={'observation_date': 'Date', 'gdp_growth': 'GDP Growth'}, inplace=True)

# %%
# Read Gross Domestic Product (GDP) dataset informaion
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        40 non-null     object
#  1   GDP Growth  40 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 772.0+ bytes

# %%
# Update data type from object to datetime
gdp_df["Date"] = pd.to_datetime(gdp_df["Date"], errors="coerce")

# %%
# Read Gross Domestic Product (GDP) dataset informaion
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        40 non-null     datetime64[ns]
#  1   GDP Growth  40 non-null     float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 772.0 bytes

# %%
# Generates a statistical summary of Gross Domestic Product (GDP) 
gdp_df.describe()
# Out:
#                       Date  GDP Growth
# count                   40   40.000000
# mean   2020-08-15 21:36:00    4.120000
# min    2015-10-01 00:00:00   -5.200000
# 25%    2018-03-09 12:00:00    2.075000
# 50%    2020-08-16 00:00:00    2.900000
# 75%    2023-01-23 12:00:00    3.950000
# max    2025-07-01 00:00:00   34.900000
# std                    NaN    6.742145

# %%
# Import Interest Rate data
interest_df = pd.read_csv("interest.csv")

# %%
# Read the top row of Interest Rate dataset
interest_df.head()
# Out:
#    obser_date  interest
# 0  1980-01-01     13.82
# 1  1980-02-01     14.13
# 2  1980-03-01     17.19
# 3  1980-04-01     17.61
# 4  1980-05-01     10.98

# %%
# Read Interest Rate dataset informaion
interest_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 553 entries, 0 to 552
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   obser_date  553 non-null    object
#  1   interest    553 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 8.8+ KB

# %%
# Rename the Columns name
interest_df.rename(columns={'obser_date': 'Date', 'interest': 'Interest Rate'}, inplace=True)

# %%
# Read Interest Rate dataset informaion
interest_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 553 entries, 0 to 552
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           553 non-null    object
#  1   Interest Rate  553 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 8.8+ KB

# %%
# Update data type from object to datetime
interest_df["Date"] = pd.to_datetime(interest_df["Date"], errors="coerce")

# %%
# Read Interest Rate dataset informaion
interest_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 553 entries, 0 to 552
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           553 non-null    datetime64[ns]
#  1   Interest Rate  553 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 8.8 KB

# %%
# Generates a statistical summary of Interest Rate
interest_df.describe()
# Out:
#                                 Date  Interest Rate
# count                            553     553.000000
# mean   2002-12-31 10:30:09.764918656       4.418282
# min              1980-01-01 00:00:00       0.050000
# 25%              1991-07-01 00:00:00       1.010000
# 50%              2003-01-01 00:00:00       4.330000
# 75%              2014-07-01 00:00:00       6.120000
# max              2026-01-01 00:00:00      19.100000
# std                              NaN       3.909951

# %%
# Import Inflation data
inflation_df = pd.read_csv("inflation.csv")

# %%
# Read the top row of Inflation dataset
inflation_df.head()
# Out:
#   observation_date  inflation_rate
# 0       2016-01-01             1.4
# 1       2016-02-01             1.0
# 2       2016-03-01             0.9
# 3       2016-04-01             1.1
# 4       2016-05-01             1.0

# %%
# Read Inflation dataset informaion
inflation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   observation_date  120 non-null    object
#  1   inflation_rate    119 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 2.0+ KB

# %%
# Rename the Columns name
inflation_df.rename(columns={'observation_date': 'Date', 'inflation_rate': 'Inflation Rate'}, inplace=True)

# %%
# Read Inflation dataset informaion
inflation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            120 non-null    object
#  1   Inflation Rate  119 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 2.0+ KB

# %%
# Update data type from object to datetime
inflation_df["Date"] = pd.to_datetime(inflation_df["Date"], errors="coerce")

# %%
# Read Inflation dataset informaion
inflation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            120 non-null    datetime64[ns]
#  1   Inflation Rate  119 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 2.0 KB

# %%
# Read the top row of Inflation dataset
inflation_df.head()
# Out:
#         Date  Inflation Rate
# 0 2016-01-01             1.4
# 1 2016-02-01             1.0
# 2 2016-03-01             0.9
# 3 2016-04-01             1.1
# 4 2016-05-01             1.0

# %%
# Merge the dummy dataset with Consumer Prices Index (CPI) dataset
test_df= pd.merge(date_df, cpi_df, how="left", on=["Date"])

# %%
# Read the top row of joined dataset
test_df.head
# Out:
# <bound method NDFrame.head of      Index       Date  Consumer price index  Changes in the CPI
# 0        1 1947-01-01                21.480                 NaN
# 1        2 1947-02-01                21.620            0.651769
# 2        3 1947-03-01                22.000            1.757632
# 3        4 1947-04-01                22.000            0.000000
# 4        5 1947-05-01                21.950           -0.227273
# ..     ...        ...                   ...                 ...
# 945    946 2025-10-01                   NaN            0.000000
# 946    947 2025-11-01               325.031            0.204397
# 947    948 2025-12-01               326.030            0.307355
# 948    949 2026-01-01                   NaN                 NaN
# 949    950 2026-02-01                   NaN                 NaN
#
# [950 rows x 4 columns]>

# %%
# Merge the dataset with Unemployment rate dataset
test_df= pd.merge(test_df, unemploy_df, how="left", on=["Date"])

# %%
# Read the top row of joined dataset
test_df.head
# Out:
# <bound method NDFrame.head of      Index       Date  Consumer price index  Changes in the CPI  \
# 0        1 1947-01-01                21.480                 NaN
# 1        2 1947-02-01                21.620            0.651769
# 2        3 1947-03-01                22.000            1.757632
# 3        4 1947-04-01                22.000            0.000000
# 4        5 1947-05-01                21.950           -0.227273
# ..     ...        ...                   ...                 ...
# 945    946 2025-10-01                   NaN            0.000000
# 946    947 2025-11-01               325.031            0.204397
# 947    948 2025-12-01               326.030            0.307355
# 948    949 2026-01-01                   NaN                 NaN
# 949    950 2026-02-01                   NaN                 NaN
#
#      Unemployment Rate
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...

# %%
# Merge the dataset with Gross Domestic Product (GDP)  dataset
test_df= pd.merge(test_df, gdp_df, how="left", on=["Date"])

# %%
# Read the top row of joined dataset
test_df.head
# Out:
# <bound method NDFrame.head of      Index       Date  Consumer price index  Changes in the CPI  \
# 0        1 1947-01-01                21.480                 NaN
# 1        2 1947-02-01                21.620            0.651769
# 2        3 1947-03-01                22.000            1.757632
# 3        4 1947-04-01                22.000            0.000000
# 4        5 1947-05-01                21.950           -0.227273
# ..     ...        ...                   ...                 ...
# 945    946 2025-10-01                   NaN            0.000000
# 946    947 2025-11-01               325.031            0.204397
# 947    948 2025-12-01               326.030            0.307355
# 948    949 2026-01-01                   NaN                 NaN
# 949    950 2026-02-01                   NaN                 NaN
#
#      Unemployment Rate  GDP Growth
# 0                  NaN         NaN
# 1                  NaN         NaN
# 2                  NaN         NaN
# ...

# %%
# Merge the dataset with Interest rate dataset
test_df= pd.merge(test_df, interest_df, how="left", on=["Date"])

# %%
# Read the top row of joined dataset
test_df.head
# Out:
# <bound method NDFrame.head of      Index       Date  Consumer price index  Changes in the CPI  \
# 0        1 1947-01-01                21.480                 NaN
# 1        2 1947-02-01                21.620            0.651769
# 2        3 1947-03-01                22.000            1.757632
# 3        4 1947-04-01                22.000            0.000000
# 4        5 1947-05-01                21.950           -0.227273
# ..     ...        ...                   ...                 ...
# 945    946 2025-10-01                   NaN            0.000000
# 946    947 2025-11-01               325.031            0.204397
# 947    948 2025-12-01               326.030            0.307355
# 948    949 2026-01-01                   NaN                 NaN
# 949    950 2026-02-01                   NaN                 NaN
#
#      Unemployment Rate  GDP Growth  Interest Rate
# 0                  NaN         NaN            NaN
# 1                  NaN         NaN            NaN
# ...

# %%
# Merge the dataset with Inflation dataset
test_df= pd.merge(test_df, inflation_df, how="left", on=["Date"])

# %%
# Read the top row of joined dataset
test_df.head
# Out:
# <bound method NDFrame.head of      Index       Date  Consumer price index  Changes in the CPI  \
# 0        1 1947-01-01                21.480                 NaN
# 1        2 1947-02-01                21.620            0.651769
# 2        3 1947-03-01                22.000            1.757632
# 3        4 1947-04-01                22.000            0.000000
# 4        5 1947-05-01                21.950           -0.227273
# ..     ...        ...                   ...                 ...
# 945    946 2025-10-01                   NaN            0.000000
# 946    947 2025-11-01               325.031            0.204397
# 947    948 2025-12-01               326.030            0.307355
# 948    949 2026-01-01                   NaN                 NaN
# 949    950 2026-02-01                   NaN                 NaN
#
#      Unemployment Rate  GDP Growth  Interest Rate  Inflation Rate
# 0                  NaN         NaN            NaN             NaN
# ...

# %%
# Read jointed dataset informaion
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Index                 950 non-null    int64
#  1   Date                  950 non-null    datetime64[ns]
#  2   Consumer price index  947 non-null    float64
#  3   Changes in the CPI    947 non-null    float64
#  4   Unemployment Rate     935 non-null    float64
#  5   GDP Growth            40 non-null     float64
#  6   Interest Rate         553 non-null    float64
#  7   Inflation Rate        119 non-null    float64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 59.5 KB

# %%
# Generates a statistical summary of jointed dataset
test_df.describe()
# Out:
#             Index                           Date  Consumer price index  \
# count  950.000000                            950            947.000000
# mean   475.500000  1986-07-17 00:34:51.789473664            123.848383
# min      1.000000            1947-01-01 00:00:00             21.480000
# 25%    238.250000            1966-10-08 18:00:00             32.800000
# 50%    475.500000            1986-07-16 12:00:00            109.600000
# 75%    712.750000            2006-04-23 12:00:00            199.550000
# max    950.000000            2026-02-01 00:00:00            326.030000
# std    274.385677                            NaN             89.214260
#
#        Changes in the CPI  Unemployment Rate  GDP Growth  Interest Rate  \
# count          947.000000         935.000000   40.000000     553.000000
# mean             0.288199           5.666524    4.120000       4.418282
# min             -1.770548           2.500000   -5.200000       0.050000
# ...

# %%
# Import GOOGL data
googl_df = pd.read_csv("googl.csv")

# %%
# Read the top row of GOOGL dataset
googl_df.head()
# Out:
#   ticker      smonth  oprice  cprice         svol
# 0  GOOGL  2004-08-01    2.50    2.56   2672137188
# 1  GOOGL  2004-09-01    2.57    3.24   4249913832
# 2  GOOGL  2004-10-01    3.27    4.77  10272433284
# 3  GOOGL  2004-11-01    4.84    4.55  11092660236
# 4  GOOGL  2004-12-01    4.55    4.82   5807878308

# %%
# Read GOOGL dataset informaion
googl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 259 entries, 0 to 258
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  259 non-null    object
#  1   smonth  259 non-null    object
#  2   oprice  259 non-null    float64
#  3   cprice  259 non-null    float64
#  4   svol    259 non-null    int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 10.2+ KB

# %%
# Rename the Columns name of AAPL dataset
googl_df.rename(columns={'smonth': 'Date', 'oprice': 'Stock Open Price','cprice': 'Stock Closing Price','svol': 'Stock Trading Volume' }, inplace=True)

# %%
# Read GOOGL dataset informaion
googl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 259 entries, 0 to 258
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ticker                259 non-null    object
#  1   Date                  259 non-null    object
#  2   Stock Open Price      259 non-null    float64
#  3   Stock Closing Price   259 non-null    float64
#  4   Stock Trading Volume  259 non-null    int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 10.2+ KB

# %%
# Update data type from object to datetime
googl_df["Date"] = pd.to_datetime(googl_df["Date"], errors="coerce")

# %%
# Read GOOGL dataset informaion
googl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 259 entries, 0 to 258
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ticker                259 non-null    object
#  1   Date                  259 non-null    datetime64[ns]
#  2   Stock Open Price      259 non-null    float64
#  3   Stock Closing Price   259 non-null    float64
#  4   Stock Trading Volume  259 non-null    int64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(1)
# memory usage: 10.2+ KB

# %%
# Merge the testdataset with GOOGL dataset
test_df = pd.merge(test_df, googl_df, how="left", on=["Date"])

# %%
# Read GOOGL dataset informaion
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Index                 950 non-null    int64
#  1   Date                  950 non-null    datetime64[ns]
#  2   Consumer price index  947 non-null    float64
#  3   Changes in the CPI    947 non-null    float64
#  4   Unemployment Rate     935 non-null    float64
#  5   GDP Growth            40 non-null     float64
#  6   Interest Rate         553 non-null    float64
#  7   Inflation Rate        119 non-null    float64
#  8   ticker                259 non-null    object
#  9   Stock Open Price      259 non-null    float64
#  10  Stock Closing Price   259 non-null    float64
#  11  Stock Trading Volume  259 non-null    float64
# dtypes: datetime64[ns](1), float64(9), int64(1), object(1)
# memory usage: 89.2+ KB

# %%
# Remove those rows with NULL records
googl_merge = test_df[test_df.notnull().all(axis=1)]

# %%
# Read GOOGL dataset informaion
googl_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39 entries, 828 to 942
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Index                 39 non-null     int64
#  1   Date                  39 non-null     datetime64[ns]
#  2   Consumer price index  39 non-null     float64
#  3   Changes in the CPI    39 non-null     float64
#  4   Unemployment Rate     39 non-null     float64
#  5   GDP Growth            39 non-null     float64
#  6   Interest Rate         39 non-null     float64
#  7   Inflation Rate        39 non-null     float64
#  8   ticker                39 non-null     object
#  9   Stock Open Price      39 non-null     float64
#  10  Stock Closing Price   39 non-null     float64
#  11  Stock Trading Volume  39 non-null     float64
# dtypes: datetime64[ns](1), float64(9), int64(1), object(1)
# memory usage: 4.0+ KB

# %%
# Read the top row of merged dataset
googl_merge.head()
# Out:
#      Index       Date  Consumer price index  Changes in the CPI  \
# 828    829 2016-01-01               237.652           -0.045844
# 831    832 2016-04-01               238.992            0.383065
# 834    835 2016-07-01               240.101           -0.050370
# 837    838 2016-10-01               241.741            0.234269
# 840    841 2017-01-01               243.618            0.404308
#
#      Unemployment Rate  GDP Growth  Interest Rate  Inflation Rate ticker  \
# 828                4.8         2.3           0.34             1.4  GOOGL
# 831                5.1         1.3           0.37             1.1  GOOGL
# 834                4.8         2.9           0.39             0.8  GOOGL
# 837                4.9         2.2           0.40             1.6  GOOGL
# 840                4.7         2.0           0.65             2.5  GOOGL
#
#      Stock Open Price  Stock Closing Price  Stock Trading Volume
# 828             38.11                38.07          1.039984e+09
# ...

# %%
# Remove columns from dataset
googl_compare = googl_merge.drop(["Index","Date","Consumer price index","ticker","Stock Open Price"], axis=1)

# %%
# Generates a statistical summary of merged dataset
googl_compare.describe()
# Out:
#        Changes in the CPI  Unemployment Rate  GDP Growth  Interest Rate  \
# count           39.000000          39.000000   39.000000      39.000000
# mean             0.253588           4.697436    4.207692       2.110513
# std              0.276973           2.072437    6.807132       1.927076
# min             -0.792015           3.400000   -5.200000       0.050000
# 25%              0.123631           3.700000    2.150000       0.355000
# 50%              0.233958           4.000000    2.900000       1.680000
# 75%              0.403551           4.750000    4.100000       4.330000
# max              0.943995          14.800000   34.900000       5.330000
#
#        Inflation Rate  Stock Closing Price  Stock Trading Volume
# count       39.000000            39.000000          3.900000e+01
# mean         3.138462            95.261282          7.435968e+08
# std          2.143487            48.276509          1.493273e+08
# ...

# %%
# Read medrged dataset informaion
googl_compare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39 entries, 828 to 942
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Changes in the CPI    39 non-null     float64
#  1   Unemployment Rate     39 non-null     float64
#  2   GDP Growth            39 non-null     float64
#  3   Interest Rate         39 non-null     float64
#  4   Inflation Rate        39 non-null     float64
#  5   Stock Closing Price   39 non-null     float64
#  6   Stock Trading Volume  39 non-null     float64
# dtypes: float64(7)
# memory usage: 2.4 KB

# %%
# Define dependent(y) and independent(X) columns from dataset
X = googl_compare[['Changes in the CPI','Unemployment Rate','GDP Growth','Interest Rate','Inflation Rate']]
y = googl_compare['Stock Closing Price']

# %%
# Read the top row of dependent (Stock Closing Price)
y.head()
# Out:
# 828    38.07
# 831    35.39
# 834    39.57
# 837    40.49
# 840    41.01
# Name: Stock Closing Price, dtype: float64

# %%
# Import library matplotlib and seaborn
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Plot pairwise relationships between variables
sns.pairplot(googl_compare, kind="scatter", plot_kws={'alpha':0.4})

# %%
# Draws a scatterplot and fits a linear regression mode
sns.lmplot(x = "Changes in the CPI",
           y = "Stock Closing Price",
           data = googl_compare,
           scatter_kws={'alpha':0.3})

# %%
# Draws a scatterplot and fits a linear regression mode
sns.lmplot(x = "Unemployment Rate",
           y = "Stock Closing Price",
           data = googl_compare,
           scatter_kws={'alpha':0.3})

# %%
# Draws a scatterplot and fits a linear regression mode
sns.lmplot(x = "GDP Growth",
           y = "Stock Closing Price",
           data = googl_compare,
           scatter_kws={'alpha':0.3})

# %%
# Draws a scatterplot and fits a linear regression mode
sns.lmplot(x = "Interest Rate",
           y = "Stock Closing Price",
           data = googl_compare,
           scatter_kws={'alpha':0.3})

# %%
# Draws a scatterplot and fits a linear regression mode
sns.lmplot(x = "Inflation Rate",
           y = "Stock Closing Price",
           data = googl_compare,
           scatter_kws={'alpha':0.3})

# %%
# Import sklearn.model, prepare for Train/test split for linear regression
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=30)

# %%
# Import Linear Regression from sklearn
from sklearn.linear_model import LinearRegression

# %%
ols = LinearRegression()
ols.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Print Coeficient, intersect and R-square
print("Intercept is:" + str(ols.intercept_))
print("The set of coeficient are:" + str(ols.coef_))
print("The R-Square value is:" + str(ols.score(X_train,y_train)))
# Out:
# Intercept is:-87.94730916392854
# The set of coeficient are:[66.75273545 18.93759601 -2.33830739 24.85547715 15.03502824]
# The R-Square value is:0.8362379120951353

# %%
# Predict the dependent y from X_test
y_pred = ols.predict(X_test)

# %%
# Import library for Mean Absolute Error, Mean Square Error and RMSE
from sklearn.metrics import mean_squared_error, mean_absolute_error 
import math

# %%
print("Mean Absolute Error: ", mean_absolute_error(y_test, y_pred))
print("Mean Squared Error: ", mean_squared_error(y_test, y_pred))
print("RMSE : ", math.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error:  35.010416217833075
# Mean Squared Error:  2384.4927710358656
# RMSE :  48.831268374227854

# %%
# Calculate the performance
performance = pd.DataFrame({'PREDICTIONS':y_pred,'ACTUAL VALUES':y_test})
performance.head()
# Out:
#      PREDICTIONS  ACTUAL VALUES
# 852    75.098680          59.11
# 915   191.205945         107.34
# 909   201.090853          94.51
# 843    53.685306          46.23
# 903   139.603278         114.11

# %%
# Calculate the error by compare the actual values with the predicted value
performance['error']=performance['ACTUAL VALUES'] - performance['PREDICTIONS']
performance.head()
# Out:
#      PREDICTIONS  ACTUAL VALUES       error
# 852    75.098680          59.11  -15.988680
# 915   191.205945         107.34  -83.865945
# 909   201.090853          94.51 -106.580853
# 843    53.685306          46.23   -7.455306
# 903   139.603278         114.11  -25.493278

# %%
# Rest Index 
performance.reset_index(drop=True,inplace=True)
performance.reset_index(inplace=True)
performance.head()
# Out:
#    index  PREDICTIONS  ACTUAL VALUES       error
# 0      0    75.098680          59.11  -15.988680
# 1      1   191.205945         107.34  -83.865945
# 2      2   201.090853          94.51 -106.580853
# 3      3    53.685306          46.23   -7.455306
# 4      4   139.603278         114.11  -25.493278

# %%
# Plot the Residuals (error) from observations
fig = plt.figure(figsize=(10,5))
plt.bar('index','error',data=performance, color='grey', width=0.3)
plt.xlabel("Observations")
plt.ylabel("Residuals")
plt.show()

# %%
# Plot the distribution of residuals
sns.displot(performance['error'], bins=15, kde='True')

# %%
# Use Normal Probability Plot (Q-Q plot) to indicate if the residuals should align the straight line
import pylab
import scipy.stats as stats
stats.probplot(performance['error'], dist="norm", plot=pylab)
pylab.show()

# %%
# Include a Constant in Statsmodels OLS
import statsmodels.api as sm
X_train = sm.add_constant(X_train)
X_train.head()
# Out:
#      const  Changes in the CPI  Unemployment Rate  GDP Growth  Interest Rate  \
# 870    1.0            0.230788                3.7         4.8           2.40
# 891    1.0            0.671331                6.1         7.0           0.07
# 876    1.0            0.192166                3.6        -5.2           1.55
# 936    1.0            0.466935                4.0        -0.6           4.33
# 846    1.0            0.032765                4.3         3.2           1.15
#
#      Inflation Rate
# 870             1.8
# 891             4.2
# 876             2.5
# 936             3.0
# 846             1.7

# %%
# Generate Ordinary Least Squares (OLS) regression 
import statsmodels.api as sm
X_train = sm.add_constant(X_train)
X_train.head()
bestfit_ols = sm.OLS(y_train, X_train).fit(cov_type="HC3")
bestfit_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Stock Closing Price   R-squared:                       0.836
# Model:                             OLS   Adj. R-squared:                  0.788
# Method:                  Least Squares   F-statistic:                     14.95
# Date:                 Tue, 17 Feb 2026   Prob (F-statistic):           1.04e-05
# Time:                         19:01:02   Log-Likelihood:                -103.20
# No. Observations:                   23   AIC:                             218.4
# Df Residuals:                       17   BIC:                             225.2
# Df Model:                            5
# Covariance Type:                   HC3
# ...
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...
