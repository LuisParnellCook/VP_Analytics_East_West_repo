# %%
import pandas as pd
import numpy as np
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
# Load abnormal returns from event study
ar_df = pd.read_csv('Data/event_study_abnormal_returns_panel123.csv')
print(f"Abnormal returns shape: {ar_df.shape}")
print(ar_df.head())
# Out:
# Abnormal returns shape: (1714, 5)
#           event_id ticker        date  event_day  abnormal_return
# 0  AAPL_2005-07-13   AAPL  2005-07-08         -5        -0.019242
# 1  AAPL_2005-07-13   AAPL  2005-07-11         -2        -0.025196
# 2  AAPL_2005-07-13   AAPL  2005-07-12         -1        -0.003679
# 3  AAPL_2005-07-13   AAPL  2005-07-13          0         0.001773
# 4  AAPL_2005-07-13   AAPL  2005-07-14          1         0.052472

# %%
# Load EPS surprise data
eps_df = pd.read_csv('data/av_eps_quarterly.csv')
print(f"EPS data shape: {eps_df.shape}")
print(eps_df.head())
# Out:
# EPS data shape: (250, 8)
#   fiscalDateEnding reportedDate  reportedEPS  estimatedEPS  surprise  \
# 0       30/09/2025   30/10/2025         1.85          1.76      0.09
# 1       30/06/2025   31/07/2025         1.57          1.43      0.14
# 2       31/03/2025   01/05/2025         1.65          1.62      0.03
# 3       31/12/2024   30/01/2025         2.40          2.34      0.06
# 4       30/09/2024   31/10/2024         0.97          0.95      0.02
#
#    surprisePercentage   reportTime symbol
# 0              5.1136  post-market   AAPL
# 1              9.7902  post-market   AAPL
# 2              1.8519  post-market   AAPL
# 3              2.5641  post-market   AAPL
# 4              2.1053  post-market   AAPL
