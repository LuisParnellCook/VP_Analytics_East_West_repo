# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
import warnings
warnings.filterwarnings('ignore')

# Set visualization style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# %%
eps_df = pd.read_csv("Data/av_eps_quarterly.csv")
regime = pd.read_csv("Data/regime_data.csv")

# %%
print(eps_df.isna().sum())

eps_df.rename(columns={"reportedDate": "earnings_date"}, inplace=True)

print(eps_df.dtypes)
print(regime.dtypes)
# Out:
# fiscalDateEnding      0
# reportedDate          0
# reportedEPS           0
# estimatedEPS          1
# surprise              0
# surprisePercentage    1
# reportTime            0
# symbol                0
# dtype: int64
# fiscalDateEnding       object
# earnings_date          object
# reportedEPS           float64
# estimatedEPS          float64
# surprise              float64
# surprisePercentage    float64
# reportTime             object
# symbol                 object
# dtype: object
# date                    object
# DGS10                  float64
# DGS10_3m_pct_change    float64
# VIXCLS                 float64
# regime                   int64
# dtype: object

# %%
print(eps_df)
print(regime)
# Out:
#     fiscalDateEnding earnings_date  reportedEPS  estimatedEPS  surprise  \
# 0         30/09/2025    30/10/2025        1.850         1.760     0.090
# 1         30/06/2025    31/07/2025        1.570         1.430     0.140
# 2         31/03/2025    01/05/2025        1.650         1.620     0.030
# 3         31/12/2024    30/01/2025        2.400         2.340     0.060
# 4         30/09/2024    31/10/2024        0.970         0.950     0.020
# ..               ...           ...          ...           ...       ...
# 245       31/01/2006    16/02/2006        0.004         0.004     0.000
# 246       31/10/2005    09/11/2005        0.004         0.003     0.001
# 247       31/07/2005    11/08/2005        0.003         0.003     0.000
# 248       30/04/2005    12/05/2005        0.006         0.002     0.004
# 249       31/01/2005    17/02/2005        0.003         0.002     0.001
#
#      surprisePercentage   reportTime symbol
# 0                5.1136  post-market   AAPL
# ...

# %%
car_data = pd.read_csv("Data/event_study_abnormal_returns_panel.csv")
print(car_data.shape)
print(car_data.head())
# Out:
# (1714, 5)
#           event_id ticker        date  event_day  abnormal_return
# 0  AAPL_2005-07-13   AAPL  2005-07-08         -5        -0.019242
# 1  AAPL_2005-07-13   AAPL  2005-07-11         -2        -0.025196
# 2  AAPL_2005-07-13   AAPL  2005-07-12         -1        -0.003679
# 3  AAPL_2005-07-13   AAPL  2005-07-13          0         0.001773
# 4  AAPL_2005-07-13   AAPL  2005-07-14          1         0.052472

# %%
eps_df["earnings_date"] = pd.to_datetime(eps_df["earnings_date"], errors="coerce")
regime["date"] = pd.to_datetime(regime["date"], errors="coerce")
